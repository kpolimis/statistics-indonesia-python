# %%
import geopandas as gpd
# %matplotlib inline

# %%
boros = gpd.GeoDataFrame.from_file('../data/new_york_gis/nybb.shp')
boros.set_index('BoroCode', inplace=True)
boros.sort_index()
# Out:
#                BoroName    Shape_Area     Shape_Leng  \
# BoroCode
# 1             Manhattan  6.364715e+08  359299.096471
# 2                 Bronx  1.186925e+09  464392.991824
# 3              Brooklyn  1.937479e+09  741080.523166
# 4                Queens  3.045213e+09  896344.047763
# 5         Staten Island  1.623820e+09  330470.010332
#
#                                                    geometry
# BoroCode
# 1         (POLYGON ((981219.0557861328 188655.3157958984...
# 2         (POLYGON ((1012821.805786133 229228.2645874023...
# 3         (POLYGON ((1021176.479003906 151374.7969970703...
# 4         (POLYGON ((1029606.076599121 156073.8142089844...
# 5         (POLYGON ((970217.0223999023 145643.3322143555...

# %%
boros.plot()

# %%
boros['geometry'].convex_hull.plot()

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
world.head()
# Out:
#        continent  gdp_md_est  \
# 0           Asia     22270.0
# 1         Africa    110300.0
# 2         Europe     21810.0
# 3           Asia    184300.0
# 4  South America    573900.0
#
#                                             geometry iso_a3  \
# 0  POLYGON ((61.21081709172574 35.65007233330923,...    AFG
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...    AGO
# 2  POLYGON ((20.59024743010491 41.85540416113361,...    ALB
# 3  POLYGON ((51.57951867046327 24.24549713795111,...    ARE
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...    ARG
#
#                    name     pop_est
# 0           Afghanistan  28400000.0
# 1                Angola  12799293.0
# 2               Albania   3639453.0
# 3  United Arab Emirates   4798491.0
# 4             Argentina  40913584.0

# %%
cities.head()
# Out:
#                                       geometry          name
# 0  POINT (12.45338654497177 41.90328217996012)  Vatican City
# 1    POINT (12.44177015780014 43.936095834768)    San Marino
# 2  POINT (9.516669472907267 47.13372377429357)         Vaduz
# 3  POINT (6.130002806227083 49.61166037912108)    Luxembourg
# 4  POINT (158.1499743237623 6.916643696007725)       Palikir

# %%
world.plot()

# %%
import time
print("last updated: {}".format(time.strftime("%a, %d %b %Y %H:%M", time.localtime())))
# Out:
# last updated: Sun, 20 Aug 2017 19:48
